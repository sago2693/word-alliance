# %%
class MultitaskBERT(nn.Module):
    '''
    This module should use BERT for 3 tasks:

    - Sentiment classification (predict_sentiment)
    - Paraphrase detection (predict_paraphrase)
    - Semantic Textual Similarity (predict_similarity)
    '''
    def __init__(self, config):
        super(MultitaskBERT, self).__init__()
        # You will want to add layers here to perform the downstream tasks.
        # Pretrain mode does not require updating bert paramters.
        #self.num_labels = config.num_labels
        self.bert = BertModel.from_pretrained('bert-base-uncased', local_files_only=config.local_files_only)
        for param in self.bert.parameters():
            if config.option == 'pretrain':
                param.requires_grad = False
            elif config.option == 'finetune':
                param.requires_grad = True
        ### TODO
        ## sst - sentiment, para, sts - semantic text similarity    
        self.drop = torch.nn.Dropout(p=0.3)
        self.sst_classifier = torch.nn.Linear(self.bert.config.hidden_size, self.num_labels_sst)
        self.para_classifier = torch.nn.Linear(self.bert.config.hidden_size, self.num_labels_para)
        self.sts_classifier = torch.nn.Linear(self.bert.config.hidden_size, self.num_labels_sts)

        raise NotImplementedError


    def forward(self, input_ids, attention_mask):
        'Takes a batch of sentences and produces embeddings for them.'
        # The final BERT embedding is the hidden state of [CLS] token (the first token)
        # Here, you can start by just returning the embeddings straight from BERT.
        # When thinking of improvements, you can later try modifying this
        # (e.g., by adding other layers).
        ### TODO
        raise NotImplementedError

# %%
from datasets import load_multitask_data, SentenceClassificationDataset, SentencePairDataset
from config import PretrainedConfig

# %%
sentiment_data, num_labels, paraphrase_data, similarity_data = load_multitask_data(sentiment_filename='data/ids-sst-train.csv',paraphrase_filename='data/quora-train.csv',similarity_filename='data/sts-train.csv')
# Out:
# Loaded 8544 train examples from data/ids-sst-train.csv
# Loaded 141498 train examples from data/quora-train.csv
# Loaded 6040 train examples from data/sts-train.csv

# %%
config = PretrainedConfig(local_files_only=True)

# %%
config.get_config_dict('bert-base-uncased')[0]
# Out:
# {'architectures': ['BertForMaskedLM'],
#  'attention_probs_dropout_prob': 0.1,
#  'gradient_checkpointing': False,
#  'hidden_act': 'gelu',
#  'hidden_dropout_prob': 0.1,
#  'hidden_size': 768,
#  'initializer_range': 0.02,
#  'intermediate_size': 3072,
#  'layer_norm_eps': 1e-12,
#  'max_position_embeddings': 512,
#  'model_type': 'bert',
#  'num_attention_heads': 12,
#  'num_hidden_layers': 12,
#  'pad_token_id': 0,
#  'position_embedding_type': 'absolute',
#  'transformers_version': '4.6.0.dev0',
#  'type_vocab_size': 2,
#  'use_cache': True,
#  'vocab_size': 30522}

# %%
class tempArgs():
    def __init__(self,):
        self.local_files_only=True

# %%
tempargs = tempArgs()

# %%
sst_train_data = SentenceClassificationDataset(sentiment_data,tempargs)

# %%
batched_sst_data = sst_train_data.collate_fn(sst_train_data.dataset)

# %%
para_train_data = SentencePairDataset(paraphrase_data,tempargs,isRegression=False)
sts_strain_data = SentencePairDataset(similarity_data,tempargs,isRegression=True)

# %%
para_train_data.dataset
# Out:
# [('how can i master myself in geometry ?',
#   'how can i master geometry for the cat-14 ?',
#   0,
#   'a4da64a4e943bf8b008d174ca'),
#  ('can deleted pictures on instagram be recovered ?',
#   'how do i delete a picture on instagram ?',
#   0,
#   'f965ab2d29d51008ab3872f47'),
#  ('who is the best prime minister india has ever had ?',
#   'who is the best prime minister of the india till now ?',
#   1,
#   '5aca073f4a977d55176f68572'),
#  ('what qualifications do i need to get a job in cern ?',
#   'what qualifications do i need to be able to work for cern ?',
#   1,
#   'a8abbd08d3401287da42acfb9'),
#  ('in what situations is it okay to lie ?',
#   'when is it okay to lie ?',
#   1,
#   '65dffaf8ac0ed7f3ebfcf0b02'),
#  ('how do off campus placements take place ?',
#   'how do i get off campus placement ?',
#   0,
#   '2c84e2535e3fda2a283c5dc14'),
#  ('what is the difference between oracle 9i and 10i ?',
#   'are oracle soa and oracle osb completely different , or one is one a part of the other one (this question comes from two architectures argument) ?',
#   0,
#   'dcd2019ba80d98b37e72303c8'),
#  ('how i can i propose for a gay sex ?',
#   'what doesit take for a man to propose ?',
#   0,
#   'a4d72591e2e6e315825e1715b'),
#  ('will the fight between the u .s . & russia end like what is shown in the video below ?',
#   'what would u .s .–russia relations be like today if russia had signed the maastricht treaty in 1991 ?',
#   0,
#   '54e578b91e1b5209b1caafbaa'),
#  ('what do nsitians think of iiit a ?',
#   'what do nsitians think of iiit h ?',
#   0,
#   '38940bb7b3fbc2419c6844b82'),
#  ('i have lost my aadhaar enrollment slip & registered mobile number as well . how do i download my aadhaar card ?',
#   "i don 't have an enrollment number or an aadhaar card number . what should i do ?",
#   1,
#   'ed0a7da62b22b76bce9bb3ceb'),
#  ('how can someone buy a legit social security card ?',
#   'where can i buy a legit social security number ?',
#   1,
#   'e5e4b155aa91c82c9d8e9e059'),
#  ('where can i get professional photo booths service in sydney ?',
#   'where can i get the best quality photo booths in sydney ?',
#   1,
#   'a946a79cc1bf4a3d3bd7f39b9'),
#  ('which are the best hollywood comedy movies that won no oscar ?',
#   'which are the best hollywood comedy movies ?',
#   0,
#   'e52929a5176c82cbed0c36571'),
#  ('what do turks and azerbaijanis think about tajikistan ?',
#   'what do azerbaijanis think of turks ?',
#   0,
#   '0ae74aadbae4ceb1364b8af02'),
#  ('how can i help my girlfriend not feel sad after sex ?',
#   'why do i not want to have sex with my girlfriend ?',
#   0,
#   'a3ec56580cc7614a60756888d'),
#  ("why did nehru sign indus water treaty which was not in india 's interest ?",
#   'why did india signed indus water treaty ?',
#   1,
#   'f4d6dfb558a0334a49202bca0'),
#  ('how can i learn megruli ?',
#   'how does one learn to learn ?',
#   0,
#   '9ba2a4d94d4008b83d6ded540'),
#  ("what 's the best mistake you 've ever made ?",
#   'what was your best mistake and why ?',
#   1,
#   '1452d08fae3e592184eb80da7'),
#  ('what universities does prosperity bancshares recruit new grads from ? what majors are they looking for ?',
#   'what universities does servisfirst bancshares recruit new grads from ? what majors are they looking for ?',
#   0,
#   'a47190b797cc1c92cf725a499'),
#  ('what is it like flying first class ?',
#   'what is like flying first class ?',
#   1,
#   '32d7b4c059f37be5a012f603d'),
#  ('which languages do not use an alphabet ?',
#   'why did chinese never evolve to use some form of alphabet ?',
#   0,
#   '4e8c448f06c70639a657c718b'),
#  ('which are some good institutes for preparation of csir net life sciences & nearby faridabad ?',
#   'which are some good institutes for preparation of csir net life sciences & nearby to faridabad ?',
#   1,
#   'aa1d83432d38f37feac75b8e6'),
#  ('how can i concentrate and focus on my studies ?',
#   'how should i concentrate on studies ?',
#   1,
#   'c27a302bf1a534981feadc606'),
#  ('what is your favorite rap song ?',
#   'what is your favorite rap song ? do answer .',
#   1,
#   '6b9b3b6c46448467f358f93b5'),
#  ('what is the tallest building in bulgaria ?',
#   'what is the tallest building in hungary ?',
#   0,
#   '76edf21d2ca7e1b287b9d18d6'),
#  ('is darth vader the greatest movie villain of all time ?',
#   "who is darth vader 's mom ?",
#   0,
#   '733e7b7968a0d2bd4732fae1d'),
#  ('which is the best ias coaching in delhi and patna ?',
#   'union public service commission (india): what are some good ias coaching centers in mumbai ?',
#   0,
#   'd6a34e2c9e5f9d2fc82302a8f'),
#  ('what is the difference between robbery , heist , burglary and dacoit ?',
#   'what should you wear to a robbery ?',
#   0,
#   '789888603126b41262173d1f3'),
#  ('how do military reserves work and when are they used ?',
#   '"what is ""staff work"" in the american military ?"',
#   0,
#   'e67ff5db68e33c950db0b5b2e'),
#  ('how do i jailbreak ios 9 .3 .4 ?',
#   'how can i jailbreak ios 8 .4 ?',
#   0,
#   '77d8e79f30440077dd35f161c'),
#  ('how do i multiply two numbers ?',
#   'how do i multiply two complex numbers ?',
#   0,
#   '24cfe8b8f4c057f5691fe69bb'),
#  ('does searching for air tickets in an incognito web browser prevent airfare search engines from increasing prices on flights that you search for often ?',
#   'how do you search for red-eye flights ?',
#   0,
#   'd207872c4761291729e4d0973'),
#  ('is it legal to question or criticize the actions of indian army or judiciary ?',
#   'do indian filmmaker have right /freedom to make those film and allow to be aired in india - anti india or very critical of the govt or its policy ?',
#   0,
#   'd5b9aa4c2da3dd7c5880c7cda'),
#  ('if a person has sexual urge and he does not sex , does his brain work slow ?',
#   'is it ok if my partner wants to talk about someone else doing me and dating me while having phone sex ? does it mean that he does not love me as he is not possessive about me ?',
#   0,
#   '3941055f5af44f345a93cf91a'),
#  ('why do they study human anatomy ?',
#   "what 's the best way to study human anatomy ?",
#   0,
#   '95c07aae1a5a26e6a8ec31886'),
#  ('how do i deal with a heartbreak of someone you loved ?',
#   "what 's the best way to deal with heartbreak ?",
#   0,
#   '42f02cbf322602e7fa1f0a47d'),
#  ('does the fbi/cia/nsa actually have the technology that we see in the movies ?',
#   'is there a real person (cia sad agent , fbi , nsa , delta force , seal , etc .) , living or dead , that is close to skills and abilities to jason bourne ?',
#   0,
#   '7823ec41023f9945f3e498665'),
#  ('"what are the disadvantages of ""gst"" bill in india ?"',
#   'is gst bill is favorable or not ?',
#   0,
#   '3481bbda05a785d324cf3ea8c'),
#  ("where 's a good university to study computer science in the uk ?",
#   'what are some good uk universities in computer science ?',
#   1,
#   '70eaaf2b039aa2f228c303f38'),
#  ('why do we need laws in society ? what would life be like without them ?',
#   'how does law change the society ?',
#   0,
#   'd17a735279dcd7a88a7456478'),
#  ('what is the event horizon in a black hole ?',
#   'what is an event horizon of a black hole ?',
#   0,
#   'd15696e56f72d095d702d74e6'),
#  ('is there any free graduate physics tutors online for the ias exam ?',
#   'i am b .tech second year c .s .e student , i did not which feild i can choose whether gate or cat or simply join a company after b .tech ?',
#   0,
#   '393c0d0c0e7d1354c97a2de21'),
#  ('which is the best iit jee coaching classes in nashik ?',
#   'which coachings aots are the best for the iit jee ?',
#   0,
#   'e4f05dd49ea3f9d49bc06e478'),
#  ('as an infp , what is your enneagram type ?',
#   'what is the enneagram theory ?',
#   0,
#   '4fdf3512ff8c661451be93a0f'),
#  ('what are the safety precautions on handling shotguns proposed by the nra in minnesota ?',
#   'what are the safety precautions on handling shotguns proposed by the nra in new hampshire ?',
#   1,
#   '6123c84963c327b914eaf225b'),
#  ('can i really do anything if i believe i can ?',
#   'if you believe enough can you really do anything ?',
#   0,
#   'a97d6f10723d294e64da2bbc7'),
#  ('i am not balding that much . can i use minoxidil ? and can i stop it later on ?',
#   'after graduating from nit jamsedpur and having 4 years of work experience in l&t , joining npcc as assistant engineer (none executive) is right ?',
#   0,
#   'd6c915cf81f203be66429f419'),
#  ('how do birds fly in perfect formations ?',
#   'how do birds fly in formation ? why do they do so ?',
#   1,
#   'a2a18505c33663124aea5e2f9'),
#  ('what would happen if copyright laws were non-existent ?',
#   'hypothetical scenarios: what would the world be like if there were no copyright laws ?',
#   1,
#   '1f9a855d850d6f34e65157f36'),
#  ('why did the us and vietnam war start ?',
#   'how many us veterans of the vietnam war are alive today ?',
#   0,
#   '392538dd3152217c1451442eb'),
#  ('what are some works of literature you associate with musical chords ?',
#   'what are some good books for a beginner who wants to study human behaviour ?',
#   0,
#   '8c58270b0f92ca701280ae101'),
#  ('what does chronological order mean ? what are some examples ?',
#   'what is chronological order ?',
#   1,
#   'dac571009596e416e85baf6e3'),
#  ('what is the saddest thing about your father and/or mother ?',
#   "what is the saddest thing you 've ever seen as a police officer ?",
#   0,
#   'f255d6019b58811ddeff2580a'),
#  ('how do you find out if your son is gay or not ?',
#   'how do i find out if my son is gay ?',
#   1,
#   '8219ebb9223490f4cd57d465f'),
#  ("what is the personal property security act and how is nova scotia 's different from manitoba 's ?",
#   "what is the personal property security act and how is nova scotia 's different from newfoundland 's ?",
#   0,
#   '8a0fdc427cb835692bd45d4a8'),
#  ('if humans evolved from apes , why are there still apes ?',
#   'if we evolved from apes then why are there still apes around today ?',
#   1,
#   '47ced81579270d54f7cc0e54e'),
#  ('is an outgoing call on jio free for life ?',
#   'are jio calls really free for life or not ?',
#   1,
#   '32fdb550616849e502143448a'),
#  ('could not get user data from social network ?',
#   "what if social networks didn 't consume any data ?",
#   0,
#   '3673e1d3eaa29f9399f9e29b9'),
#  ('how do i search in quora ?',
#   'how do you search on quora ?',
#   0,
#   '43eafd128b3abf0d73497c836'),
#  ('what are some examples of popular sovereignty ?',
#   'what is popular sovereignty ? what are some examples ?',
#   1,
#   '15b451bce606fa5fef0b883fc'),
#  ('what are the characteristics of nerve impulse ?',
#   'what pathway do nerve impulses take ?',
#   0,
#   '27c6ba07308485e041a71d57b'),
#  ('can a brain transplant be done ?',
#   'could a brain transplant be possible within our lifetime ?',
#   1,
#   '27e3d2a6b6e698f438a1f1499'),
#  ('what was the average life expectancy of a soldier in world war ii ?',
#   'what are the 5 most honest world war ii films ?',
#   0,
#   'f8a617313297db74b19917ad9'),
#  ('how can i travel to other countries for free ?',
#   'how can i travel around the world for free ?',
#   1,
#   '18697014a033c397877aaf824'),
#  ('what are some good and bad benefits of banning 500 and 1000 rupees notes in india ?',
#   'what are the pros and cons of banning 500 and 1000 rupee notes in india ?',
#   1,
#   'e9f1e28ec2e7f4582f9a3464d'),
#  ('how common is it for women to ejaculate (squirt) during orgasm ?',
#   'what does it feel like for a woman to have an orgasm ?',
#   0,
#   '32aea49b4dc9ccd09e60f16da'),
#  ('when on instagram if you have a private account can the people you follow see your pictures ?',
#   "my instagram account is set to private . if one of my followers hit a like in my picture , will it appear to others that aren 't following me ?",
#   0,
#   'ab404b15b68dad3e2c804b312'),
#  ('what are some of the best mottos to live by ?',
#   'what is the main motto of living life ?',
#   0,
#   '4baf24468ce22fbcf8e425788'),
#  ('how are the day to day lives of people who were born completely blind and those who became completely blind later in life different ?',
#   'why is detachment so hard ?',
#   0,
#   '223727ff0a6a7cd641586fa10'),
#  ('how can i retrieve and recover deleted items from my gmail after mistakenly deleting and clearing trash ?',
#   'how can i recover my emails from my gmail account ?',
#   1,
#   '02b4d883167ff1d21a935adeb'),
#  ('will wwe ever go out of business in the future ?',
#   'how do you catch group c strep ? how is it treated ?',
#   0,
#   'c321c81c5bb66da9247abd855'),
#  ('does donating blood help you lose weight ?',
#   'how can i lose weight quickly ?',
#   0,
#   'c91b2e780c852a803be34834a'),
#  ('who is most likely to be president of the united states on january 20th , 2017 ?',
#   'who will be president of the united states ?',
#   1,
#   '220eccdc21364159cbeb77d98'),
#  ("passport: while filling up my application form i made a mistake in my mother 's name spelling , and submitted the application . how can i rectify it ?",
#   'passports: i have filed my online passport application form , submitted it and taken an appointment also . but now i have found a mistake in it . can i rectify it at the psk on the appointment date ? what can i do now ?',
#   0,
#   'bfbecb07b9285a1c29585d8ac'),
#  ('how often people have sex in relationships ?',
#   'how do people have sex ?',
#   0,
#   '6c6ee96a236d1b81f6cd9c999'),
#  ("what was the exact sequence of events for the 1999 coup d 'etat in pakistan ?",
#   "what is coup d 'état ?",
#   0,
#   '7c7483f8f82f72ef4fe7d4478'),
#  ('what is best way to increase presence of mind ?',
#   'is there any way to develop my presence of mind ?',
#   1,
#   'd6b49c74db2d2c223c13cf752'),
#  ('what are ionic compounds ?',
#   'are ionic compounds molecules ?',
#   0,
#   '5a8cc6ff61ac77be002e7b3dd'),
#  ('what is the source of income for the person who runs mo vlogs and what is his real name ?',
#   'who is mo vlog ?',
#   0,
#   'bfe70b62dd2d97e45729af364'),
#  ('how can i become a pro at clash of clans ?',
#   'did anyone go to town hall level 11 in clash of clans without paying any real world money ?',
#   0,
#   'd033af3cbbdd0c53209df974f'),
#  ('household income $280k and able to pay $130k down payment , can i buy a house in san francisco ?',
#   'should i buy a house in san francisco bay area right now ?',
#   0,
#   '809cbd24ee06f610f92c1e47f'),
#  ('how accurate is the cl iim profilizer ?',
#   'is it worth doing an mba from baby iims or should i take cat again and try for older , better iims ? my profile details are in the comment .',
#   0,
#   '18bae0d5cf4bdb2891055ca1e'),
#  ('what should i do to reduce weight ?',
#   'how can i lose 4kg weight ?',
#   1,
#   '83d331c2997c8d3236f02f385'),
#  ('what is the psychology behind a person who is uncomfortable around you when she is alone but acts very friendly with you when she is with her friends ?',
#   "i have a friend and i am interested in her . she acts like she 's interested in me but denies it when asked . what do i do ?",
#   0,
#   '13923191d3cea34cd61f096be'),
#  ('what does bjarne stroustrup think of c++ ?',
#   'how did bjarne stroustrup turn c into c++ ?',
#   0,
#   'ecccf8b30daf780d2cfc65bda'),
#  ('as a teacher , has there ever been a moment where you were flabbergasted or stunned by something someone did ?',
#   'what is the python conda root on ipython ?',
#   0,
#   '5efe2b6afdf34f6c579345b0f'),
#  ('what are some mind blowing coincidences ?',
#   'what are some mind-blowing coincidences in science ?',
#   0,
#   '59b8cd85ca47a4ece6d6b45ba'),
#  ('what are words for technical dumb charades ?',
#   'what are some words for dumb charades ?',
#   0,
#   'c8f12d9b17fd336d2aeb522c3'),
#  ('is it possible to feel true love more than once in your life ?',
#   '"can you be ""in love"" more than once ?"',
#   0,
#   '5d690a04eddaedb0a97b0fddc'),
#  ('where can i learn python for absolutely beginner for free ?',
#   'where can i learn python for free ?',
#   1,
#   'ac627a5e0933c871632bb912c'),
#  ('what is resistive touchscreen and capacitive ?',
#   'what is a capacitant ?',
#   0,
#   '28ace3924683d87b64188b6c7'),
#  ('what is the procedure of retest in nmat exam ?',
#   'how is the recommended amount of suboxone determined ? what factors are considered ?',
#   0,
#   '05c9be373102af8ab06917ca5'),
#  ('how can i take advantage of quora to improve myself ?',
#   'what are some creative ways to use quora ?',
#   0,
#   '0367a56d0527541a86c45b53d'),
#  ('where are indoor badminton clubs located around rajajinagar in bangalore ?',
#   "i 'm a 23 year old girl living in bangalore . what are some suggestions for clubs around me from which i can improve my skills ?",
#   0,
#   '13359efde27009b62b32e1abb'),
#  ('what is the best browser for facebook ?',
#   'which browser is best to open facebook ?',
#   1,
#   '32dc7cc7c99aa57e49c4d4675'),
#  ('"what \'s the difference between ""organization"" and ""organisation"" ?"',
#   'what`s the difference between trusted and trustworthy ?',
#   0,
#   '199bc777553ede3a47bea91b1'),
#  ('can you get pregnant 2 days before your period has ended ?',
#   'can you get pregnant 8 days before your period ?',
#   1,
#   '83e17296011b4f135baf41917'),
#  ('how can i dress to hide my belly fat ?',
#   'i have very sore leg muscles even after 7 days of workout , is it normal ?',
#   0,
#   '80efe5cf281e459ab520a6cc3'),
#  ('how can i retrieve old kik messages to my email ?',
#   'how do i send old kik messages to my email ?',
#   0,
#   'fc7bc426e660b71ee0b886ab8'),
#  ('how can i specifically improve my english ?',
#   'what should i do to improve my english ?',
#   1,
#   '5a8d7a779553254c1ad805e77'),
#  ('what is the difference between strong , retain , nonatomic , etc . , in the objective-c (ios) property ?',
#   'what is the difference between atomic and nonatomic property in objective c with some example ?',
#   0,
#   '979fa9af27a178bf81e82d8d9'),
#  ('what are some good mutual funds to invest in at the moment ?',
#   'are mutual funds worth the investment ?',
#   0,
#   '47678c832cc9f3827147c2e68'),
#  ('what are the chances of ww3 in 2017 ?',
#   'is ww3 inevitable ?',
#   1,
#   '8018a021869473e63641ca66a'),
#  ('what is qualitative research ? what are the limitations and delimitations ?',
#   "was the eric trump foundation caught funneling cancer research cash directly to eric trump 's father , donald trump ?",
#   0,
#   '9823ff46d112200470d9aeb78'),
#  ('renewing indian passport while working in different country , what should we choose present address . planning to apply during temporary visit to india ?',
#   'are we overusing gadgets in day-to-day life ?',
#   0,
#   '1c20224ffe50ef0b4df4ccf59'),
#  ('how are dna methylation and histone acetylation related to epigenetics ?',
#   'what causes dna methylation and histone acetylation ?',
#   0,
#   'e36a37947def010e56211e362'),
#  ('how can i delete a message sent by me in a group in whatsapp ?',
#   "can i delete whatsapp messages that haven 't been sent yet ?",
#   0,
#   '8806ec22e049f20dd9e78880f'),
#  ('is structural analysis the hardest subject in engineering ?',
#   'structural engineering: what are the main differences between sap2000 and etabs ? which one is better for building analysis and design ?',
#   0,
#   '50a84ee83f631beacc075fa18'),
#  ('can i make 40 ,000 a month playing poker ?',
#   'can i make 50 ,000 a month playing poker ? why or why not ?',
#   1,
#   'bf03ab549ebe7f0b074ca1f34'),
#  ('is it physically possible to travel back in time ?',
#   'is it actually possible to travel through time ?',
#   1,
#   '4f4a5ac7f3b0fff26068e0b60'),
#  ('"what does it mean to ""follow"" a question on quora ?"',
#   'when you follow someone on quora , do you see everything they write ? what does it mean ?',
#   0,
#   'd7288683b4d09bfbd7ded99d1'),
#  ('is ticketluck a reputable site for purchasing tickets ?',
#   'how can i buy tickets on damai ?',
#   0,
#   '59952a95e43d7c1ed1e63dfec'),
#  ('what should i do if i forgot my icloud password ?',
#   'how do i get my icloud password ?',
#   1,
#   'fec7b07770d4b9bd68d91ab6f'),
#  ('how has south korea avoided economic stagnation like japan ?',
#   'sap course for computer science course ?',
#   0,
#   'ac5db9c71f2a498528d07f848'),
#  ('is it possible for diabetes to skip a generation and then reappear again ?',
#   'why do diseases skip generations ?',
#   0,
#   '08db78784bd3dc829cf3767bb'),
#  ('what does robert kubica do for living now ?',
#   'who can be considered as the greatest scientist of all the time ? why ?',
#   0,
#   '8db5aac62a67db147c52eeaaf'),
#  ('what is the difference between an apartment and a condominium ?',
#   'where do i find condominium buyers in the philippines ?',
#   0,
#   '6f937b2d87c496912cf1b06a2'),
#  ('what are the major characteristics of nonsocial people ?',
#   'what is the reason why herbalife is bad for you ?',
#   0,
#   '962df7b4960e7104b567b3764'),
#  ('how can one learn hacking step by step ?',
#   'how should i learn hacking by myself ?',
#   1,
#   '8ba282ed7f84d10b78970290f'),
#  ('what impact did imperialism have on india ?',
#   "what is the impact of imperialism in today 's india ?",
#   1,
#   '29fd356eaca66fc534e257839'),
#  ('how do you get a text to someone who has blocked your number ?',
#   'how do you call someone if they have blocked your number ?',
#   0,
#   'e84cbde6a2bdfaf327324edb8'),
#  ('what is the most shocking thing you saw your sister do ?',
#   "what is the best thing you 've ever learned on quora ?",
#   0,
#   'e8a8316dc7321886d4d7abf57'),
#  ('in language c and c++ what is # this name ?',
#   'how can i import goods to malaysia being a foreigner staying in kuala lumpur for studies ?',
#   0,
#   '9ca2a4092120f186b91fd2496'),
#  ('how do you train a dog ?',
#   'how can i train my dog ?',
#   1,
#   '66c043feeb70774cb640e3435'),
#  ('how does apple maps get the real time traffic data ?',
#   'how does apple maps get traffic details for a route ?',
#   1,
#   'b2b80fc4b0fc853b6e6157db0'),
#  ('what would be a blissful day ?',
#   'what is blissfulness ?',
#   0,
#   '208ed1a88d900980a5aff49e8'),
#  ('what do people with narcissistic personality disorder feel when they have to admit they are wrong or have been proven they are wrong ?',
#   'do people with narcissistic personality disorder ever feel intense loneliness ?',
#   0,
#   'd97daecc1d0f8bccc4853ed02'),
#  ('if universe expands and vacuum energy is created with it (with no limit) ,is there infinite potential energy/infinite vacuum energy that can be created ?',
#   'if energy is created and not conserved in an expanding universe (that expands without limit) can infinite energy be created then ?',
#   1,
#   '91a30181f91792e2b19ce8c1a'),
#  ('where can i find accurate study materials for the 400-101 exam ?',
#   'where can i find accurate study materials for the 70-433 exam ?',
#   0,
#   '194feb43efbf98acee2951252'),
#  ('is the housing market going to crash ?',
#   'when is the california housing market going to crash ?',
#   0,
#   'fbef84a432c7f9e571d8cfe1b'),
#  ('if i lay in bed for hours in the dark , can it qualify as rest/a form of mild sleep ?',
#   'if i have a flight booked with one airline with a long layover , does that mean i can leave my bag(s) checked and not deal with it as i wander out in the city for a few hours ?',
#   0,
#   'e2b90301d2db89c11b2ff85f4'),
#  ('how do gay (and lesbian) people have sex ?',
#   'how do people have sex ?',
#   0,
#   '0367458883d2f3b55fe03e60c'),
#  ('what should i earn monthly to be considered rich in the philippines ?',
#   '"what would make you feel ""yeah , i \'m rich"" ?"',
#   0,
#   '32359e2bc33fadfdf589dc4b3'),
#  ("why don 't muslims worldwide speak out against radical islamic groups that do immeasurable damage to their brand of religion/cult ?",
#   "if islam is so against blasphemy , why don 't muslims kill the terrorists who bring a bad name to their religion ?",
#   0,
#   'c807845bed2fe8dcb15e808a7'),
#  ('why not people accept homeopathy ?',
#   'why do people disregard homeopathy ?',
#   1,
#   '52d1bd8cd3c191a96d5875d7d'),
#  ('should i text the girl i like all day every day ?',
#   "when a girl chats with you (and only you) on the internet until very late every day , is there any possibility that she 's in love with you ?",
#   0,
#   '66cf1539d3cc78a3c41f2c5b9'),
#  ("is it possible to visit to saudi arabia with dubai 's visa ?",
#   'my tancet score is 48 i belong to bc category which college i expect through counselling ?',
#   0,
#   '10222e41dd907d02d847f4a81'),
#  ('who are some lesser known important historical figures of qatar and what should people know about them ?',
#   'who are some lesser known important historical figures of bulgaria and what should people know about them ?',
#   0,
#   '08ffc34341da52cbcd31f1ecf'),
#  ('why should i answer a question on quora ?',
#   'why should i answer quora questions ?',
#   1,
#   'd2e815ac4529d3e04cd34e680'),
#  ('what are the safety precautions on handling shotguns proposed by the nra in michigan ?',
#   'what are the safety precautions on handling shotguns proposed by the nra in new jersey ?',
#   1,
#   'c9f27e4cedd809c42556c6e56'),
#  ("what is your prediction on the economy growth in the next four years ? what was the state of economy growth during president obama 's tenure ?",
#   'what were some of the farming tools used in mesopotamia ? are they still used ?',
#   0,
#   '6ac4a86af09e4baabd1c4308c'),
#  ('what does squirting feel like ?',
#   'what is squirting ?',
#   0,
#   '6dd7cbc67b7ee6b9d454d3640'),
#  ('what is oscillator ?',
#   'what is the s&p oscillator used for ?',
#   0,
#   '36ead25763ea9d45be31ba596'),
#  ('how does it feels to get spanked by stranger ?',
#   'how does a man or woman feel when they have to marry a stranger ?',
#   0,
#   '6b986467d069d395d356de4c7'),
#  ('what is depression exactly ?',
#   'what is depression for you ?',
#   1,
#   '56e3388db448c8559480a16af'),
#  ('what are the most annoying questions that you feel ridiculous in quora ?',
#   'what are the most annoying questions that you come across in quora ?',
#   1,
#   'bb05f145e1be5a74c1ecafad5'),
#  ('why ac circuits need complex analysis ?',
#   'why does a generator use ac and not dc circuit ?',
#   0,
#   '17bd6858ff5eac0aa23e48a28'),
#  ('is there any legit way to get a free xbox live gold membership code ?',
#   'how can i get a xbox live membership for free ?',
#   0,
#   '020712ebe69c264385666d878'),
#  ('do americans watch and play cricket ?',
#   "why don 't americans play cricket ?",
#   0,
#   'd5f7045a31b8af54c37327df9'),
#  ('why is queen victoria important to world history ?',
#   'did people like queen victoria ?',
#   0,
#   '59e0faed7ae81072dea3fe9cb'),
#  ('how can i delete my quora account in one minute ?',
#   'how do i unsubscribe and delete my quora account ?',
#   1,
#   'c382a8995f19c3b2857617d9e'),
#  ('who will win the us election in 2016 ?',
#   'who will win the 2016 u .s . presidential election and why ?',
#   1,
#   '074ef08ab977e1aa5fc7f4997'),
#  ('when does aurora borealis occur ? what causes it ?',
#   'why do aurora borealis appear ?',
#   1,
#   'b8a44c79ab9854073637ba3dd'),
#  ('what would your past self tell your future self ?',
#   'are private school teachers generally happier than public school teachers ?',
#   0,
#   '4686c07c4faa40e34503a3557'),
#  ('things: what do you think happens only in india ?',
#   '"can you give some examples about ""it happens only in india ?"" ?"',
#   1,
#   '6aa92612184bf9e476668aab1'),
#  ('how do i know a married man wants me (a gay guy) ?',
#   'how do you know when a married man is in love with you ?',
#   0,
#   '7053fb229ed81919bf0a1b16b'),
#  ('which is a suitable solar panel installation provider near nevada city , california ca ?',
#   'which is a suitable solar panel installation provider near sunnyvale , california ca ?',
#   0,
#   '2a436d1648f7f58f34a3a85ae'),
#  ('do indians still believe that they were rich before british misrule in india ? why ?',
#   'on what basis do indian people claim that before colonization , india was the richest country ?',
#   0,
#   'cb58a46b98bb80a204ef5fab2'),
#  ('what is the value of pi ?',
#   'what is the value of pi ?',
#   1,
#   '368fb7b242698a2b4ac94fbfb'),
#  ('how does the hp officejet 4620 airprint compare to the hp designjet z5200 44-in photo printer ?',
#   'how does the hp officejet 4620 airprint compare to the hp designjet t1530 36-in postscript printer ?',
#   1,
#   '513806c63264452c7029a5a83'),
#  ('which is the best bca colleges in lucknow ?',
#   'which is the best bca college in lucknow ?',
#   1,
#   '0433e2eac4e7983696776ee39'),
#  ('how can i calculate the conversion rate on facebook ?',
#   'how do you calculate the conversion rate for your facebook page ?',
#   1,
#   'ae4c4a37922c5a264b84b644a'),
#  ('when is amniocentesis performed ?',
#   'what is amniocentesis in biology and how is it used ?',
#   0,
#   '73c6b9c0461be7aa240e8daa2'),
#  ('who is winning the us presidental election ?',
#   'who will win the us election ?',
#   1,
#   '8c2a2ccd191f65a73294fa9a0'),
#  ('what is the easiest way to get an it job in canada ?',
#   'how does one get a job in canada ?',
#   0,
#   'daefee1448fb8fbe237eafdd2'),
#  ('what is it like being black in australia ?',
#   'what is it like to be black (african migrant or african american) in australia ?',
#   1,
#   '94045df3b9e24d5eb29fa84fa'),
#  ('any hippie places to visit in goa ?',
#   'which is the best place to visit in goa ?',
#   0,
#   '0356206b59f3ea27e90213aec'),
#  ('what prompted wheel of fortune to use the letters r s t l n and e in the bonus round ?',
#   'what is the price is right wheel made of ?',
#   0,
#   '711759b6715313f5bb1bbda92'),
#  ('what are some of the best youtube music channels ?',
#   'what are the different music youtube channels ?',
#   0,
#   '3ca56a12ad9bde3807ee44097'),
#  ('can the caste system be eradicated from india ? if so , how ?',
#   'what are your ideas for eradication of caste system from india ?',
#   1,
#   'ba833712ff227560b4a64030e'),
#  ('what does it mean when the police take a report and they suspend it ?',
#   '"what does it mean when you file a police report and the police later tell you it \'s suspended ""basically closed"" ?"',
#   0,
#   '7233514c4b6e1ae56c338d2d9'),
#  ('which laptop should i buy , dell or hp ?',
#   'which all in one i should buy , dell , lenovo or hp ?',
#   0,
#   '9a032536ebf47ff0e79b5e84e'),
#  ('where can i learn to sing exclusively online ?',
#   'how/where can i learn to sing online ?',
#   1,
#   'd278070d19cbafed30e7e84d8'),
#  ('what is the significance of bicsi cec ?',
#   'which authority is able to track ssn ?',
#   0,
#   '47c8ff0903e3fc025699337be'),
#  ('super smash bros . brawl: what is the best jigglypuff strategy ?',
#   'super smash bros . brawl: what is the best strategy against jigglypuff ?',
#   1,
#   'afaf82b8223aebb1eb59fafc0'),
#  ('why has skype suddenly become so unreliable ?',
#   'why does skype suddenly start appearing when i log in to my computer ?',
#   0,
#   '997def7c772408f76ea3e0836'),
#  ('where or how can a data-analytics-modeler work less than 25hrs per week ?',
#   'how can i understand boys mind ?',
#   0,
#   'e617644e88480fd1a744d4c09'),
#  ("why do dogs like to smell other dogs ' butts ?",
#   "why do cats and dogs smell each other 's butts ?",
#   1,
#   '7a6938e372fb1c963e78c8d63'),
#  ('assuming you could pick any time to time-travel . what would you bring (data , books , equipment) with you assuming you had time to prepare ?',
#   'if you could force five people from any time in the past or present to play russian roulette with you until only half the group remained , would you do it , and if so , who would you pick ?',
#   0,
#   '26c231499bcf25197b77096c8'),
#  ('why is engineering more favoured in india ?',
#   'why is engineering more favoured ?',
#   0,
#   '88232ea0f4c370a26ff2c62ba'),
#  ('what are pros and cons of 500 and 1000 currency notes abolishing ?',
#   'what are the pros and cons in the various sectors of the indian economy by banning indian rupees of 500 and 1000 notes ? what lead to this short notice by pm narendra modi ?',
#   1,
#   '438c297ad458028d3c9c1ec99'),
#  ('how did jimmy wales get the idea of creating wikipedia ?',
#   'how did jimmy wales get the idea of founding wikipedia ?',
#   1,
#   'd702d9dd2bf393b30521ca525'),
#  ('why the electrons did not vanish from solar cell ?',
#   "does moore 's law apply to solar cells ? why or why not ?",
#   0,
#   'b3d838daea2798e594abc794a'),
#  ('how late have you ever gotten behind on your car payment ? did the lender work with you ?',
#   'have you ever romantically pursued someone you work with ? how did it work out and how did you do it ?',
#   0,
#   'b7bbd222375beb7504a4fbbca'),
#  ('how widely accepted are credit cards at small businesses and restaurants in kuwait ?',
#   'how widely accepted are credit cards at small businesses and restaurants in italy ?',
#   0,
#   '2846725e40f574d546405acfa'),
#  ('what are some good sources about ottoman history ?',
#   'what is a good accessible book on the ottoman empire ?',
#   1,
#   '9ccaab4ef1ce2c4223a9b8e73'),
#  ('is it better to exercise 20 minutes every day or 40 min every other day ?',
#   'how would walking 3 .5 mph for 30 mins every day improve mental health ? would it make any difference on my day-to-day mood ?',
#   0,
#   '0de24fe3cef68245bd9e5bc02'),
#  ('what are the difference between jquery versions ?',
#   'what is the difference between front end and back end development ?',
#   0,
#   'b504be85682b0e8474472104b'),
#  ('what are the best aspects of living in jakarta as a young adult ?',
#   'bestradyance skin brightening complex . ?',
#   0,
#   '6583db7edf2926acab2ac4754'),
#  ('how can i transfer money from one bank to another ?',
#   'how do banks transfer money to one another ?',
#   0,
#   '05c41c9cc71680b943a8abc20'),
#  ('what budget belt grinder would you recommend for a beginner knife maker ?',
#   'what belt grinder should a (beginner) knife maker own ?',
#   1,
#   '8e777f76963c6e85d520dd070'),
#  ('how do cnc and vmc machinery work deeeply . ?',
#   'what is the difference between cnc and vmc ?',
#   0,
#   '5d2bf16fb6e5edf9f7dd50006'),
#  ('how do i approach a guy ?',
#   'how can approach guy i like ?',
#   1,
#   '3c1e6c6302526f115dce0bd5c'),
#  ('which direction is the best for sleeping ?',
#   'what is the best direction for sleeping ?',
#   1,
#   '7605e13c32a340f1dc47149ce'),
#  ("what is the difference between 'due process of law ' and 'procedure established by law ' ?",
#   'what is the difference between law of demand and law of supply ?',
#   0,
#   '85d3d998ab5dd13895b837f1b'),
#  ("what 's punjab 's growth rate ?",
#   'what is the growth rate of real gdp per capita ?',
#   0,
#   '003e8271435e2585e9e3374d2'),
#  ('what are all the food standards available for fruit products ?',
#   'why did bobby deol become a dj ?',
#   0,
#   '7f8c7cfa683cc4498b3fc1982'),
#  ('how do i download the apk from the google play store to a pc ?',
#   'how can i download .apk files from the playstore onto my pc ?',
#   1,
#   '2eceeae23f045178efb389cb5'),
#  ('what is the meaning of below sign ?',
#   'what are the meanings of these signs ?',
#   0,
#   '16634a4469c1c25607d8815eb'),
#  ('does resultsource .com have any competitors ?',
#   'are salescrunch .com and goinstant .com competitors ?',
#   0,
#   'b2a88dcfb437f5a9e89626066'),
#  ('where can i find the best wedding planners online ?',
#   'what are the best online portals to find good wedding planners ?',
#   0,
#   'e363fb226f333e2c41357e0b6'),
#  ('who was associated with environmental determinism ? what were his major contributions ?',
#   'what is the best country in eu for early-stage startups ?',
#   0,
#   'dc1c6706d0a6605e86e126a32'),
#  ('what are covalent bonds ? how do they occur ?',
#   'what is the meaning of covalent bond ?',
#   1,
#   '346aa76c4e44a3a2b0099b8f8'),
#  ('i am a bsc it graduate and work as a business analyst in bank .would icwa help enhance my opportunities ?',
#   'i am currently working as a business analyst in a product company . what do i have to do next ?',
#   0,
#   'cac0c0d5e80b3c952b08e7ef4'),
#  ('if god created us then who created him ?',
#   'if god created us , then who created him ?',
#   1,
#   '0a29bf792ebed5dba36b57145'),
#  ('what is the sahara , and how do the average temperatures there compare to the ones in the sonoran desert ?',
#   'what is the sahara , and how do the average temperatures there compare to the ones in the namib desert ?',
#   1,
#   '4455ce7c7903967d16e6754c3'),
#  ('how can one become a good orator ?',
#   'how do i become a good orator ?',
#   1,
#   '1e4f051404e1cfdd3f3d3bba1'),
#  ('how can we control anger ?',
#   'what is the best treatment for controlling anger ?',
#   1,
#   '3d340dc226b60183c2699ca1f'),
#  ('what are the benefits of learning python programming ?',
#   'what is the benefit in learning python language ?',
#   1,
#   'dbc2465481b7a3102916a63af'),
#  ('"what are some interesting facts about meredith grey , the fictional character from ""grey \'s anatomy"" ?"',
#   "is grey 's anatomy medically accurate ?",
#   0,
#   '623f6c1441ef69c43453928f6'),
#  ('is there anywhere in the world offering pain management for peripheral neuropathy as opioids haved been banned in us ?',
#   'the pain of any human being anywhere in the world causes sorrow for a fellow human being .do you agree ?',
#   0,
#   '598e7860505ba8be061270d9a'),
#  ('what are signs my guy friend is flirting with me ?',
#   'what are signs that your guy friend/ buddy is flirting with you (we are both in our mid twenties) ?',
#   1,
#   '872a18f3b602786e79b39a891'),
#  ('how do i sell a property ?',
#   'how do i sell my property in noida ?',
#   0,
#   '0ea91612ccda03c2128463cad'),
#  ('why is life not worth living ?',
#   'when do you think that life is worth living ? why ?',
#   0,
#   '6545a244315df886f087ede19'),
#  ('what are the best creative commons websites for music ?',
#   'what are the best sites to download creative commons music ?',
#   1,
#   '3194905180c04876e783ae8b3'),
#  ('my 7 year old daughter just found out she needs glasses . i have read that the need for glasses can go away as the eyes grow , what are the stats on this happening ?',
#   'what age should i be letting my kids go clubbing ? my 16 year old daughter keeps on asking me if she can go .',
#   0,
#   '9745631ef25c317f638918768'),
#  ('my percentage in 10th is 90 .2 . my 12th percentage is 78 .2 and my b .tech cgpa is 6 .5 . what is my chance for making it into iim a , b or c ?',
#   'what are the rules at the iims ?',
#   0,
#   '5e2e31b51d0a6511d44496f2d'),
#  ('what is the average number of women a man has sex with during his lifetime ?',
#   'do all women like oral sex ?',
#   0,
#   '78e752445482e4d038affcc91'),
#  ('which indian colleges admit students on the basis of sat scores ?',
#   'do colleges keep sat/act scores and high school transcripts for students they reject ? do i need to resend them if i apply again after one year ?',
#   0,
#   '3dfb51db418b95d8c79533945'),
#  ('what are the best online or offline dictionary for chines people to learn english ?',
#   'is there any good online or offline dictionary for chines people to learn english ?',
#   1,
#   '3b01f05ed8a561e3699d8005f'),
#  ('what is the best medical care for a jack russell/west highland white terrier mix ?',
#   'what is the best medical care for a terrier/border collie mix ?',
#   0,
#   '01d6206922eb458f287b910d3'),
#  ('did your opinion about john green change after you found out that he used to smoke ?',
#   'i found out that my nearly 18 year old brother and sister started smoking cigarettes before the wedding trip . do i have a right to say something ?',
#   0,
#   '97161757aad57f3b0d720b69a'),
#  ('how do i fly an airplane ?',
#   'how do you fly a plane ?',
#   1,
#   'a29e29df3a4a0356fb248865b'),
#  ('who is the most famous contemporary singer/band in german-speaking world ?',
#   'who is your favorite singer/band from your country ?',
#   0,
#   '133024697930bccccb311a7ca'),
#  ('how much rank is needed in the gate exam for textile engineering to get admission into nitie mumbai ?',
#   'how much rank is needed in the gate exam for civil engineering to get admission into nitie mumbai ?',
#   0,
#   '3fcaa0a737411fb7d7b6f32bb'),
#  ('what benefit do uploaders on torrent sites get from uploading pirated copies of films , books or other content ?',
#   'how do people benefit from uploading torrents ?',
#   0,
#   '4d374739d5f241d4ac64a383f'),
#  ('what is the way to download hindi and punjabi songs directly on iphone without syncing with itunes ?',
#   'how can i download music albums ?',
#   0,
#   'dc34e3f274874b15d7be16b16'),
#  ('what are questions which have no answers ?',
#   'what are some of the questions which has no answers ?',
#   1,
#   '388e48ffb821168b32f8cbe79'),
#  ('what are the steps to get the uan number for my pf account ?',
#   'can anyone guide me with uan / pf account ?',
#   0,
#   '81eb5b0d960da9143cc4994ac'),
#  ('where do steroid hormones have hormone receptors ? why ?',
#   'is insulin a steroid hormone ?',
#   0,
#   '77a84b8a3dc6b59b759b96b92'),
#  ('what if we throw atomic bombs in a black hole ? , will it increase its strength ?',
#   'how are black holes formed ?',
#   0,
#   'f3bb5a8416fbf1d5c087440d0'),
#  ('my boyfriend is 6 months younger than me , is that bad ?',
#   'what problems will i face if my husband is 6 months younger than me ?',
#   1,
#   '3d825e75260318f1f0055b212'),
#  ('is one sitting degrees valid for every jobs in india ?',
#   'is there a one year or two year valid degree program for diploma holders in india ?',
#   0,
#   '8513a958c81ca7291ec582fd8'),
#  ('what is the one thing that you want to change about yourself ?',
#   'what is one thing you wish you could change about yourself ?',
#   1,
#   '84d7cf8c043719503df484684'),
#  ('do employees at tyler technologies have a good work-life balance ? does this differ across positions and departments ?',
#   'do employees at agilent technologies have a good work-life balance ? does this differ across positions and departments ?',
#   0,
#   'bd74211491736f02ecf259ddb'),
#  ('if the focal length of a double convex lens is 20cm , then what is its focal length in water ?',
#   'i have a convex lens of focal length 20cm ,size 50mm . what should be the focal length and size of the other convex lens to make a powerful telescope ?',
#   0,
#   '04ab0e848c772303af9f9a6dc'),
#  ('is there a way to explore fast wikipedia articles and related wikipedia links to build the graph of its pages structure ?',
#   'how do i get rid of the odour of varnish applied on tiles ?',
#   0,
#   'da2682439dd80c0a428efcd80'),
#  ('how do you cook slightly frozen chicken ?',
#   "what 's the fastest way to cook a frozen chicken breast ?",
#   0,
#   'fa0c1123248f2cd37a58ba06e'),
#  ('psychology of everyday life: what are some little things that make people happy ?',
#   'what is happiness ? and what are the things that makes you happy ?',
#   1,
#   '9894bc3ffd33b492501028fe5'),
#  ('how do i delete old instagram account without the password or email ?',
#   'how can i delete my instagram account if i forgotten the email i used ?',
#   1,
#   '99e91bed47da541714cb73255'),
#  ('i got 753 rank in aiims and i have not attended to 1 at counseling . will i am eligible for second and third counseling ?',
#   'how much percentile should i aim for , to get into an iim in cat 2016 ?',
#   0,
#   '872f3fb8287ed3e7367e8e9a9'),
#  ('which are the top 20 twitter influencers to follow if you are a start up and want to connect ?',
#   'what is the average number of syllables spoken per minute in a normal sentence ?',
#   0,
#   'e770f3993eac788660b378674'),
#  ('how should i avoid procrastination ?',
#   'what is the best way to kill procrastination ?',
#   1,
#   '1a4fff5b45e3606f5c58880c8'),
#  ("what 's the shadiest tactic you 've witnessed hr use at your job ?",
#   'is delaying part of the google hr/recruiting negotiation tactic ?',
#   0,
#   '9c5e1af5330c57a783796bb29'),
#  ('how do i lose weight ?',
#   'what is the fastest possible way to lose weight ?',
#   1,
#   'd6054ea0e786faae8ed28dfac'),
#  ("in what year was indian currency released with mahatma gandhi 's photo on it ?",
#   'when did mahatma gandhi first appear on indian currency ?',
#   0,
#   '3e4d34f726416065eb065fd12'),
#  ('what are some top jobs in wildlife in india ?',
#   "i see average students from ordinary universities in india pursuing master 's of science degrees in the us , and after graduation , they get jobs in top companies like amazon and microsoft . what job profiles are they offered by these companies ?",
#   0,
#   '1182f25b54aa1591795e4acc8'),
#  ('which is the best medical college ?',
#   'which one is the best medical college hostel in india ?',
#   0,
#   '7e04cae19631321b8191efae4'),
#  ('how do i get rid of sores in mouth ?',
#   'how do you get rid of a mouth blister ?',
#   0,
#   '908ab3bce622d58e3df57be56'),
#  ("there have been 3 to 5 times in my life that i 've been so angry that i have switched off . i see only red air around me . anyone know what this is ?",
#   "i 've been in a relationship for the past 5 years . nowadays she is with me but not as a girlfriend . she said that she has lost such types of feelings . i want her back in my life like the old times . what should i do to bring her back ?",
#   0,
#   '395ea8c022525e4b252353920'),
#  ('what is the atomic mass of methane ? how is it determined ?',
#   'what is the atomic mass of bromine ? prove it ?',
#   0,
#   'cad381e8ad490b553b51b4d0d'),
#  ('what is software define network ?',
#   'what is software-defined networking (sdn) ?',
#   0,
#   '727723e9e876b7725e7b57739'),
#  ('how do you say ‘prodotto notevole’ in english ?',
#   'how can i say 色迷迷的 in english ?',
#   0,
#   '14a1f44c02dfe05fb42655ea4'),
#  ('how can i increase my penis ?',
#   'how do i enlarge the length and width of my penis ?',
#   1,
#   '7c778fd548e2b232a941c438e'),
#  ('which is the best college for fine arts in pune ?',
#   "which is the best college for a 'bachelor of fine arts ' in pune ?",
#   0,
#   'babbc66a98abe12bb544184e1'),
#  ('which hand muscles are used in writing ?',
#   'are extra ocular muscles used for accommodation ?',
#   0,
#   'e1528ab0d2a569b304f9915a6'),
#  ('how do you get over somebody you cant live a day without ?',
#   'how can i get over somebody i really love ?',
#   1,
#   'be215570df9b6a9b0f9f8c723'),
#  ('i’m very much interested in computers , what are the opportunities after my inter ?',
#   'i am very much interested in computer science but unfortunately i have taken up commerce , what options do i have after my graduation ?',
#   0,
#   'fc2c5d0e012b156c62746cb42'),
#  ('how hard are the sat subject tests ?',
#   'what are sat subject tests ?',
#   0,
#   '367ea2163ac44e932abc1e574'),
#  ('how are the top businessmen like ambani , tata , etc . affected by demonetization ?',
#   'how has demonetization affected big business people like mukesh ambani ?',
#   0,
#   '5122f7787a511c9270295f1ab'),
#  ('what is the cost of tea standardised by indian railways for selling in trains ?',
#   'how do i apply for industrial training for e .c . branch in indian railway ?',
#   0,
#   'd663d97e8f4fc56413df4d2dd'),
#  ('why do we look different in the mirror and photos ? and how can we make both look similar ?',
#   'why do i look good in the mirror but bad in photos ?',
#   1,
#   '395c4cdd5a10a35bf896514ad'),
#  ('which is the best institute to learn digital marketing (job oriented) in india ?',
#   'what are the best digital marketing courses for mid-senior level marketing managers ?',
#   1,
#   '2ffb4626af71cd208030389dd'),
#  ('how do i find the love of my life ?',
#   'how do i find a love of life ?',
#   1,
#   '851fcdeb1b2e650634129f960'),
#  ('i got the pokemon y rom but i cannot find the emulator . where can i find it ?',
#   'how can i play pokemon x and y on a pc ?',
#   1,
#   '445563e2262171a6b3222c818'),
#  ('"why does quora often show the ""this question needs clarification"" message ?"',
#   'why is my question marked as needing improvement when it is perfectly clear and well written ?',
#   0,
#   '120245c1e83b228d3b3fb77eb'),
#  ('how can one overcome the fear of speaking in public ?',
#   'should i overcome my fear of public speaking ?',
#   1,
#   'eafbb89e3ec23e3d3bf3c667c'),
#  ('what follows the g2 phase ?',
#   'what are the eight phases of meiosis ? how do they occur ?',
#   0,
#   'e0c8479c1fcc7887e1b507a01'),
#  ('how do i handle my anger issues ?',
#   'what do i do to have anger management ?',
#   1,
#   '0f6e9544876d1d71f6f28fd16'),
#  ('how do i add a location to my business page on facebook ?',
#   "can a facebook page check-in to a place ? or , what 's the best location service for a page to use ?",
#   0,
#   'b7e76bb7e791dfa9b343d6d50'),
#  ('how do i write a letter to the bank for an address change ?',
#   'how do you address a formal letter to a family ?',
#   0,
#   '9c49d02365d959af5d260ed88'),
#  ('what motivates people with technical experience to answer questions on quora ?',
#   'what pleasure do people get from answering questions on quora ?',
#   1,
#   'ba88b225346f9da50131e9483'),
#  ('why we need to study ?',
#   'why we need study ?',
#   1,
#   '71731d83321f84c948c52f380'),
#  ('what are the best keywords for mobile company website and why ?',
#   'which is the best keywords for website development company ?',
#   0,
#   'bdc6efe6e509de16f5b099fb1'),
#  ('how can i apply for internship in maruti suzuki ?',
#   'does maruti suzuki recruit off campus ?',
#   0,
#   '80f22addbdd9c333a959940de'),
#  ('how can i send money from the usa to dubai ?',
#   'what is the best way to send money from the uae to the usa ?',
#   0,
# ...
#  ('do spiritually awakened persons have sex ?',
#   'are you spiritually awakened ?',
#   0,
#   '8b402c817ea3d62e90699cd1d'),
#  ('hurricane sandy (october 2012): what are stores selling out of as people prepare for the storm to hit ?',
#   'what was the impact of hurricane sandy ?',
#   0,
#   '949ea9e652a31b41efcd7d2a1'),
#  ('can an email which has been deleted from the trash box of gmail be retrieved ?',
#   'how can i recover my emails from my gmail account ?',
#   0,
#   'bcdad40a97faebfadd7e992af'),
#  ('what are benefits of being a teacher ?',
#   'what are some benefits of being a teacher that outweigh the bad ?',
#   1,
#   '9ef090c18d6c7cb7992dd5cb8'),
#  ('how can some people still believe the world is flat ?',
#   'why are there still people who believe the world is flat ?',
#   1,
#   'a6af31e45d7fcbe859723a968'),
#  ('what are the arguments for and against brexit ?',
#   'what were some arguments for and against brexit ?',
#   1,
#   '32a371ce5b124bf81fc841260'),
#  ('what does a commercial barrister in the uk actually do ?',
#   'how difficult is it to become a barrister in the u .k ?',
#   0,
#   'b476b5931e03c22ad9758df0a'),
#  ("i 'm turning 18 . what advice would you give me based on your experience ?",
#   'i am an indian , i am a 16 year old girl who wants to become a supermodel when i turn 18 . can somebody help me , give me an advice or could tell me where should i go ?',
#   0,
#   '310b851949d0ebb7fa34c6dd8'),
#  ('are aliens demons ?',
#   'fallen angels: does the bible view aliens as demons ?',
#   1,
#   '91da90ff755c3c0428a58fc6f'),
#  ('how safe is the paleo diet ?',
#   'is a vegetarian paleo diet safe ?',
#   0,
#   'f22519038b0a1e9e337b26ed6'),
#  ('what is a strip club like ?',
#   'does india have strip clubs ?',
#   0,
#   '755c0e09532f8fd4d178dbfb9'),
#  ('what are the different types of map scales ?',
#   'what are the different types of maps ?',
#   0,
#   'ba3e6d25940b1b7efae46a4e4'),
#  ('how is the life of a commercial pilot in india ?',
#   'what is the scope of a commercial pilot in 2017 in india ?',
#   0,
#   '2c08af65281cd6d1da981b55e'),
#  ('how do i replace a clash of clans account on a new phone with an older account from another phone ?',
#   'could the new haste spell replace the rage spell in clash of clans ?',
#   0,
#   'cea14584a9af0249f9017fc20'),
#  ('could you give me some movie or series titles that are idioms or expressions ? for example: house of cards , blue bloods or lost in translation .',
#   '"what do you think of movies that start with ""the"" in the title ?"',
#   0,
#   '832b30e602fba5d1d1dc7c1f0'),
#  ("i judge everybody and only find out flaws . i don 't respect anybody; not even myself . how to sort it out ?",
#   "i don 't have jio sim no . on its pack . what should i do ?",
#   0,
#   '16e279593a91fcd05c50291b3'),
#  ('"how is the new harry potter book ""harry potter and the cursed child"" ?"',
#   'how bad is the new book by j .k rowling ?',
#   1,
#   '219f5e7c016875b59cad8538b'),
#  ('how much do strippers make at scores ?',
#   'how much do strippers make ?',
#   0,
#   '8e9fd6a8d5bde554992c7a1e2'),
#  ('what is hillary clinton`s stance on india ?',
#   "what is hillary clinton 's stand on relations with india ?",
#   1,
#   'c8c8315f3555317f4aa765c71'),
#  ('what is the worst place to live in india ?',
#   'what is the worst place in the world to live ?',
#   0,
#   '16d619f2bd09454ec9cca91c7'),
#  ('the role of press in democracy ?',
#   'can i leave mashed potatoes on the counter for 8 hours and reheat them ? or would they be spoiled ?',
#   0,
#   '1b608469bc5c55a453d5f557a'),
#  ('would you prefer to be a man like steve jobs or a man who lived in alaska with no responsibility or pride ?',
#   "what life advice would you give to a wife who lives with a man who does not talk to her or anyone else in the family , lost his job 5 years ago , and doesn 't talk to his children ? she manages the household on her own . is it okay for her to just be happy managing things and enjoying the kids ?",
#   0,
#   'ff5ba79666c1be6941082a114'),
#  ('what mean by alkali ?', 'what is alkali ?', 1, 'f9a87e56701bd6394cb51c352'),
#  ('this is scam website ?',
#   'how do i check if any website is a scam or legit ?',
#   1,
#   'da9c8d48718ab164b130845ea'),
#  ('"what does it mean men say ""need to take some time"" in a relationship ?"',
#   '"what does it mean when a guy says ""need some time"" in a relationship ?"',
#   1,
#   '6b41c196df9a55d2660d9540f'),
#  ('what are the safety precautions on handling shotguns proposed by the nra in new hampshire ?',
#   'what are the safety precautions on handling shotguns proposed by the nra in georgia ?',
#   1,
#   '592ba4e8bf9612493090247cf'),
#  ('what is your favorite pokémon in pokémon go ?',
#   'what is your favorite pokémon and why ?',
#   0,
#   '3f964d97f9f7a444077969fd9'),
#  ('is it realistic that sherlock does not know the identity of one of the characters ?',
#   'how did sherlock know vivian was the one who betrayed agra ?',
#   0,
#   '86d7de0078b46d6738bc7ad28'),
#  ('how do i lose stubborn belly fat ?',
#   'what are some good ways to get rid of belly fat ?',
#   1,
#   '3fdbdba405ef4e12c91734920'),
#  ('what are the risks of letting your mom sleep in bed with you ?',
#   'how do i get my wife to let me sleep in the bed ?',
#   0,
#   '29d92361a5a3f688407084976'),
#  ('what are the best cello strings ?',
#   'is p2p lending in china basically a scam , as claimed by the ceo of fosun ?',
#   0,
#   'bd577f94e1fbbf406268b3672'),
#  ('can you un-merge a question in quora ?',
#   'how do you unmerge questions on quora ?',
#   1,
#   '820cbb1f8f89d55b20ad76887'),
#  ('what is the difference between pressure relief valve and pressure control valve in real life application ?',
#   'what is pressure override in pressure relief valve ?',
#   0,
#   '048996afc141593a9ca3b2c76'),
#  ('what is it that we indians are collectively doing good ?',
#   'what are the things that indians are collectively doing in the right way ?',
#   1,
#   'ee76f124d643d64b9c5e4d69a'),
#  ('how do i know if i’m an extrovert ?',
#   'how will i know whether i’m an introvert or an extrovert ?',
#   1,
#   'ab3a7e18af85df04eeafd6a74'),
#  ('why would you want to be in a relationship ?',
#   'why did you want a relationship ?',
#   1,
#   'd7cd93fd4d9f2cb7950b8face'),
#  ('how many deals does groupon\\ livingsocial sale in a month ?',
#   'what were the results of the david gray/groupon deal ?',
#   0,
#   '2d419796b3f4e72e1ebb2d9b2'),
#  ('how do i get in touch with a small scale garment manufacturing unit in calcutta ?',
#   'how do i get in touch with small scale garment manufacturing unit in bangalore ?',
#   0,
#   '2fd07fc9752fdc16b9101be80'),
#  ('both my parents are from norway , but i learned english fluently when i was 5/6 years old . am i bilingual ?',
#   'i speak good english with my countrymen but when i am with people from english speaking countries i mess up . how do i cure this ?',
#   0,
#   '98e2a1dcfa9502130c16a4f5e'),
#  ('which is the best pub in indiranagar , bangalore ?',
#   'which are the cheap and best pub in bangalore ?',
#   0,
#   'd3eea27683ba7d0f1ef36df94'),
#  ('what is limp home mode in a car ?',
#   'what is a vw limp mode ?',
#   0,
#   '97a2f390625d435f91dc5ed1b'),
#  ('has anyone settled a medical malpractice case directly with the doctor ? i am in california .',
#   'am a medical doctor in nigeria . how can i work and live in australia ?',
#   0,
#   'fbb9e34790c2a25aa78a3a90f'),
#  ("how do calculators claculate logarithms ? what 's the algorithm they use ?",
#   'how do calculators calculate logarithms ?',
#   1,
#   '642df916826bd1fe6f6c799ab'),
#  ('what is the purpose of life ? why are we here ?',
#   'what could be the basic purpose of life ?',
#   1,
#   'f4499df63c30db68e5e2c31c8'),
#  ('what it was like to grow up in bihar when lalu and later his wife ruled the state ?',
#   'what is it like to grow up in bihar ?',
#   0,
#   '64102c7ae8ab49d0c9e1f8a67'),
#  ('"what was hitler \'s primary goal: to rule the world , create the perfect human race or rid the world of ""vermin"" ?"',
#   'what races would have been allowed to live had hitler won world war ii ?',
#   0,
#   '795c0cc82c445f9505de6fcfe'),
#  ('why has quora flagged this question as needing improvement ?',
#   'why does quora always mark my answer as need for improvement ?',
#   1,
#   'ab3c31070fa68c390e20ed37c'),
#  ('what are the best sites for downloading movies ?',
#   'what are the best sites to download movies ?',
#   1,
#   '5de5adda4d58bc86512d6638c'),
#  ('have mages been scientifically tested ?',
#   'have sorcerers been scientifically tested ?',
#   1,
#   'e32127f1afbba4c948b6a68ea'),
#  ('what is the most messed up thing you have ever done ?',
#   'why does most of the guys gets messed up in a relationship ?',
#   0,
#   'ba7b28c838e1a04730413a4d0'),
#  ('how can i make my hair grow faster in a month ?',
#   'what can i do to make my hair grow faster ?',
#   0,
#   '66098cb1abc7ede2d8c27e15e'),
#  ('how do i stop my american staffy/kelpie mix from humping my furniture ?',
#   'how do i stop my australian shepherd/border collie mix from humping my furniture ?',
#   1,
#   '1d6b73ade8bf6067719b010d5'),
#  ('what are the best places to visit in srilanka ?',
#   'what are best places to visit srilanka ?',
#   1,
#   '415012cf57d73b092d2167e7f'),
#  ('why is displacement in nth second= displacement/ time ?',
#   'why do we assume displacement due to transverse load as negative second differential term ?',
#   0,
#   '21aadd3e81a26c9d1eb91ca3b'),
#  ('do you need special shoes for crossfit training ?',
#   'which shoes would provide the best heel support while doing crossfit training ?',
#   0,
#   'dae7a84e2f046969825d986d2'),
#  ('is the united states a republic or a democracy ?',
#   'is the united states of america a republic or a democracy ?',
#   1,
#   'e3f19e3b0793117492bc17047'),
#  ('what is the best website for forex trading ?',
#   'what is the best website for forex and trading ?',
#   1,
#   '0155bd970366da78bee611ed9'),
#  ('why does my girlfriend refuse to have sex with me ?',
#   'how do i have sex with my girlfriend ?',
#   0,
#   'afb515bf86a053c9e3aad94fa'),
#  ('what is the sweetest thing ?',
#   'what is the sweetest thing you can do for your mother ?',
#   0,
#   '9ca77742f1af37fe358920156'),
#  ('what is the worst advice you have ever got ?',
#   'what was the worst advice you have ever received ?',
#   1,
#   'ebd1a88390f3cbd58e8e47c61'),
#  ('as a ug cse graduate , can i join companies like lockheed martin and dassault ?',
#   'how do i convert commercial licence of 4wheelar into personal licence ?',
#   0,
#   '10a741b9295ae73efc4463ebf'),
#  ('why and what makes some things burn when heated ?',
#   'why do things burn ?',
#   0,
#   '380a235f0e1f677b66e3d34ec'),
#  ('how is it possible for cops to trace a lost mobile using the imei number even after the sim card has been taken out ?',
#   'how do i find a sim card number using an imei number ?',
#   0,
#   'e9b477e8e42bbaa0598a273ac'),
#  ('why do some people think americans are stupid ?',
#   'why are americans deemed stupid ?',
#   1,
#   '41071605ada2bf71473b7d130'),
#  ('what is the salary range for classification level l in stanford university ?',
#   'what is the salary range for classification levels g in stanford university ?',
#   0,
#   '9c71d9662aedad5e29ec5e54e'),
#  ('how often did steve jobs read books ?',
#   'when i read about steve jobs , i become depressed comparing myself to him at my age (which is 29) . what actions can i take to solve this problem ?',
#   0,
#   '43f91510b0595c4fa24c21e72'),
#  ('what is the best website for the preparation of elitmus ?',
#   'what is the best website to prepare for the elitmus and amcat ?',
#   0,
#   'e5f026863cb197324cd1eb435'),
#  ('what is the best diet for fat loss ?',
#   'how can i lose weight quickly ?',
#   0,
#   'ff3543428ab5baf14beee80f6'),
#  ('who view my instagram video ?',
#   'how do i see who viewed my instagram video ?',
#   1,
#   '27cace6178b358d03e00df620'),
#  ('"what are ""tapes"" in extensions ?"',
#   'do you use tape extension ?',
#   0,
#   'cc6dac33b1a26830f9eee714d'),
#  ('what does ‘[math]![/math]’ as in [math]n![/math] mean in math ?',
#   'what does ~ mean in math ?',
#   0,
#   '333bf0a48611f6348fc1d2d9a'),
#  ('which party will win in punjab ?',
#   'which party will win election in 2017 in punjab ?',
#   1,
#   '1bfdc2e11d61d884e72375376'),
#  ('i’m searching for a coding bootcamp in amsterdam , but i can find only 3 coding school . someone knows more ? wish to learn java/javascript',
#   'how do i learn coding in c in 3 months ?',
#   0,
#   '6c9a18cb3fa28f5ee22f7d4f8'),
#  ('what universities does splunk recruit new grads from ? what majors are they looking for ?',
#   'what universities does the gap recruit new grads from ? what majors are they looking for ?',
#   0,
#   '8e4fc6ed02bc3dc47e337bd8d'),
#  ("what 's the best way to learn how to sing ?",
#   'how do i learn how to sing ?',
#   1,
#   '5aca04c358ac92d520c78b32c'),
#  ('what is meant by a stock exchange ?',
#   'what is meant by stock exchange ?',
#   1,
#   '4fb20391084552ed9d9ae36c3'),
#  ('can i prevent my daughter who is a felon from moving with me ?',
#   "my parents introduced me to a very pretty girl , who is the daughter of my mom 's friend . i recently found out that she is having sex for money . it completely broke me . no one else knows this but me . she is now asking me to move in with her , and promised to stop . should i trust her ?",
#   0,
#   '0fb249a41114cab426eb2c177'),
#  ('what is the meaning of investments by owners ?',
#   'what do you mean by investment ?',
#   0,
#   '4e79b0834f9f6e9b157c1d856'),
#  ('facebook: how do i get fake likes on a facebook status ?',
#   'how do i get people to like my anime facebook page ?',
#   0,
#   'cfed231717cad855c2b5c434b'),
#  ('why is narendra modi promoting jio ?',
#   'is it morally correct for our prime minister narendra modi to appear in advertisement of reliance jio ?',
#   1,
#   '9613e20a7592c301a2b0e4123'),
#  ('how do i build a home gym on a budget ?',
#   'home gym: what should i buy first ? a pull up bar or a squat rack ? what is more essential ?',
#   0,
#   '82853bc1570793adb1addd7ed'),
#  ('what are the health downsides of eating farmed salmon ?',
#   "what 's with the alleged toxicity of farmed salmon ?",
#   1,
#   '720dd3067fd5371a832318405'),
#  ('why do few boys blush in front of girls ?',
#   'should i just close my heart to women ?',
#   0,
#   'ea85107e5aec576261ddc56e1'),
#  ("when i 'm alone i crave attention , but when i have attention i want to be left alone . why ?",
#   'i want to be alone , i want to be left alone . what is the difference ?',
#   0,
#   '294053d49f665a1ebedef4c0f'),
#  ("how embarrassing is it to be 30 years old and have never had a girlfriend and can 't find a career you are passionate about ?",
#   "i 'm 14 and i just had sex for the first time , i feel so guilty and bad about myself , like i 'm a failure . why do i feel this ? how do i feel better ?",
#   0,
#   'daeeec2c7e15a7c4417afe549'),
#  ("how would i know if there 's been suspicious activity on my instagram ?",
#   'how do i know if there is suspicious activity on my instagram account ? will i get notified ?',
#   1,
#   'b87f5d018e6759acae6f62f6c'),
#  ('is it okay to eat two meals a day ?',
#   'what will happen if i eat only two meals per day ?',
#   1,
#   '56f4568f3b01a690d3e287e0f'),
#  ('what percent of emails do professors not read ?',
#   'what percent of undergrads do professors like ? what percent do they dislike ?',
#   0,
#   'ebbf909e7085706dc92ee128f'),
#  ('what are common required and elective courses in nursing ?',
#   'what are common required and elective courses in medicine ?',
#   0,
#   '693e0f48f379dddcbd99b07e3'),
#  ('how do i earn from quora ?',
#   'how can we earn from quora ?',
#   1,
#   'bb848d59f331ef11b7b461df0'),
#  ('can you get pregnant from oral sex ?',
#   'can i get pregnant from oral sex ?',
#   1,
#   'b3159f2dc8faca5f8edd5e3f9'),
#  ('how do i beat laziness ?',
#   'how can i beat laziness ?',
#   1,
#   '13fa9cb293310e06cb599f1ba'),
#  ('what is the salary of a pediatric surgeon in australia ?',
#   'what is the average salary of an indian surgeon ?',
#   0,
#   'e46328f30c60920894b4ee625'),
#  ('how can i gain root access to my java phone ?',
#   'is one plus one a rooted phone ?',
#   0,
#   '5054501515ac2bec7fa4f1377'),
#  ('how to run whatsapp on pc without bluestacks',
#   'what are the ways to use whatsapp on pc other than bluestacks ?',
#   1,
#   '1a34dcf058ad79d7816c88f9f'),
#  ...]

# %%
batched_para_data = para_train_data.collate_fn(para_train_data.dataset)

# %%
batched_para_data.keys()
# Out:
# dict_keys(['token_ids_1', 'token_type_ids_1', 'attention_mask_1', 'token_ids_2', 'token_type_ids_2', 'attention_mask_2', 'labels', 'sent_ids'])

# %%
batched_para_data['token_ids_1']
# Out:
# tensor([[  101,  2129,  2064,  ...,     0,     0,     0],
#         [  101,  2064, 17159,  ...,     0,     0,     0],
#         [  101,  2040,  2003,  ...,     0,     0,     0],
#         ...,
#         [  101,  2054,  2024,  ...,     0,     0,     0],
#         [  101,  1999,  1038,  ...,     0,     0,     0],
#         [  101,  2054,  2003,  ...,     0,     0,     0]])

# %%
batched_para_data['token_ids_2'].shape
# Out:
# torch.Size([141498, 286])

# %%
class BertModel(BertPreTrainedModel):
  """
  the bert model returns the final embeddings for each token in a sentence
  it consists
  1. embedding (used in self.embed)
  2. a stack of n bert layers (used in self.encode)
  3. a linear transformation layer for [CLS] token (used in self.forward, as given)
  """
  def __init__(self, config):
    super().__init__(config)
    self.config = config

    # embedding
    self.word_embedding = nn.Embedding(config.vocab_size, config.hidden_size, padding_idx=config.pad_token_id)
    self.pos_embedding = nn.Embedding(config.max_position_embeddings, config.hidden_size)
    self.tk_type_embedding = nn.Embedding(config.type_vocab_size, config.hidden_size)
    self.embed_layer_norm = nn.LayerNorm(config.hidden_size, eps=config.layer_norm_eps)
    self.embed_dropout = nn.Dropout(config.hidden_dropout_prob)
    # position_ids (1, len position emb) is a constant, register to buffer
    position_ids = torch.arange(config.max_position_embeddings).unsqueeze(0)
    self.register_buffer('position_ids', position_ids)

    # bert encoder
    self.bert_layers = nn.ModuleList([BertLayer(config) for _ in range(config.num_hidden_layers)])

    # for [CLS] token
    self.pooler_dense = nn.Linear(config.hidden_size, config.hidden_size)
    self.pooler_af = nn.Tanh()

    self.init_weights()

  def embed(self, input_ids): #input_ids_1, input_ids_2
    
    input_shape = input_ids.size()
    seq_length = input_shape[1]

    # Get word embedding from self.word_embedding into input_embeds.
    inputs_embeds = self.word_embedding(input_ids)

    # Get position index and position embedding from self.pos_embedding into pos_embeds.
    pos_ids = self.position_ids[:, :seq_length] #subsets a list of positions 0:512 to 0:seq_length. 

    pos_embeds = self.pos_embedding(pos_ids)


    # Get token type ids, since we are not consider token type, just a placeholder.
    tk_type_ids = torch.zeros(input_shape, dtype=torch.long, device=input_ids.device)
    tk_type_embeds = self.tk_type_embedding(tk_type_ids)

    # Add three embeddings together; then apply embed_layer_norm and dropout and return.
    hidden_states = inputs_embeds+pos_embeds+tk_type_embeds
    hidden_states = self.embed_layer_norm(hidden_states)
    hidden_states = self.embed_dropout(hidden_states)

    return hidden_states


  def encode(self, hidden_states, attention_mask):
    """
    hidden_states: the output from the embedding layer [batch_size, seq_len, hidden_size]
    attention_mask: [batch_size, seq_len]
    """
    # get the extended attention mask for self attention
    # returns extended_attention_mask of [batch_size, 1, 1, seq_len]
    # non-padding tokens with 0 and padding tokens with a large negative number 
    extended_attention_mask: torch.Tensor = get_extended_attention_mask(attention_mask, self.dtype)

    # pass the hidden states through the encoder layers
    for i, layer_module in enumerate(self.bert_layers):
      # feed the encoding from the last bert_layer to the next
      hidden_states = layer_module(hidden_states, extended_attention_mask)

    return hidden_states

  def forward(self, input_ids, attention_mask):
    """
    input_ids: [batch_size, seq_len], seq_len is the max length of the batch
    attention_mask: same size as input_ids, 1 represents non-padding tokens, 0 represents padding tokens
    """
    # get the embedding for each input token
    embedding_output = self.embed(input_ids=input_ids)

    # feed to a transformer (a stack of BertLayers)
    sequence_output = self.encode(embedding_output, attention_mask=attention_mask)

    # get cls token hidden state
    first_tk = sequence_output[:, 0]
    first_tk = self.pooler_dense(first_tk)
    first_tk = self.pooler_af(first_tk)

    return {'last_hidden_state': sequence_output, 'pooler_output': first_tk}
